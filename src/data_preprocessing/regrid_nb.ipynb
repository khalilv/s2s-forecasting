# %%
import xarray as xr
import numpy as np 
from matplotlib import pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
orig_fp = '/u/gracefo-m0/DATA_SERVER/s2s.dir/era5/2m_temperature/2m_temperature_1979.nc'
regrid_fp = '/u/gracefo-m0/DATA_SERVER/s2s.dir/era5_1.40625/2m_temperature/2m_temperature_1.40625deg.nc'
orig_ds = xr.open_dataset(orig_fp)
regrid_ds = xr.open_dataset(regrid_fp)

# %%
orig_ds['t2m'][578].plot()
plt.show()

regrid_ds['t2m'][578].plot()
plt.show()
